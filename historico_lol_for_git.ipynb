# %%
import pandas as pd

# %%
#Baixando o CSV com os dados de 2011-2022

df = pd.read_csv('champions_stats.csv')

df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  \
# 0            18                          6.0   12     6  ...
# 1            13                          4.0    8     5  ...
# 2             2                          2.0    2     0  ...
# 3             8                          5.0    3     5  ...
# 4             4                          2.0    2     2  ...
#
#    kill_death_assist_ratio  creep_score  cs/min  gold  gold/min  damage  \
# ...

# %%
#Faço um tratamento para conciliar Season com o ano vigente 
#Como a ideia é virar um Index, é mais tranquilo organizar por ano do MSI/Mundial
 
df['ano'] = pd.to_datetime(2000 + 10 + df['season'], format='%Y') + pd.offsets.DateOffset(months=0, days=0)
df['ano'] = pd.to_datetime(df['ano']).dt.year
df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  creep_score  \
# 0            18                          6.0   12     6  ...        90.17
# 1            13                          4.0    8     5  ...       114.00
# 2             2                          2.0    2     0  ...       162.00
# 3             8                          5.0    3     5  ...       224.63
# 4             4                          2.0    2     2  ...       206.50
#
# ...

# %%
df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  creep_score  \
# 0            18                          6.0   12     6  ...        90.17
# 1            13                          4.0    8     5  ...       114.00
# 2             2                          2.0    2     0  ...       162.00
# 3             8                          5.0    3     5  ...       224.63
# 4             4                          2.0    2     2  ...       206.50
#
# ...

# %%
#Criando o dataframe pro gráfico

df_new = df[['champion', 'games_contests', 'ano']]
df_new.head()
# Out:
#        champion  games_contests   ano
# 0          Nunu              27  2011
# 1       Alistar              25  2011
# 2        Rumble              23  2011
# 3      Vladimir              22  2011
# 4  Twisted Fate              22  2011

# %%
#Nesta etapa o que fazemos é somar ano a ano os campeões para criar um acumulado.

df_chart = df_new.pivot_table(
    index='ano',
    columns='champion',
    values='games_contests',
    aggfunc='sum'  # ou 'mean', 'max', etc. conforme seu caso
)

df_chart = df_chart.rename_axis(None, axis=1).reset_index()

# %%
#Conferindo o resultado
df_chart.head()
# Out:
#     ano  Aatrox  Ahri  Akali  Alistar  Amumu  Anivia  Annie  Aphelios  Ashe  \
# 0  2011     NaN   NaN    7.0     25.0   18.0    14.0   10.0       NaN  19.0
# 1  2012     NaN   2.0    NaN     19.0    1.0    19.0    NaN       NaN   NaN
# 2  2013    36.0  52.0    NaN      NaN    NaN     NaN   12.0       NaN   7.0
# 3  2014     6.0  13.0    1.0     78.0    NaN     NaN    NaN       NaN   NaN
# 4  2015     NaN   3.0    NaN     33.0    NaN     6.0   10.0       NaN  13.0
#
#    ...  Yasuo  Yone  Yorick  Yuumi   Zac   Zed  Ziggs  Zilean  Zoe  Zyra
# 0  ...    NaN   NaN     NaN    NaN   NaN   NaN    NaN     7.0  NaN   NaN
# 1  ...    NaN   NaN    11.0    NaN   NaN   NaN    NaN     2.0  NaN   4.0
# 2  ...    NaN   NaN     3.0    NaN  17.0  63.0    1.0     1.0  NaN  48.0
# 3  ...   30.0   NaN     NaN    NaN   NaN  38.0    2.0    75.0  NaN   NaN
# 4  ...   12.0   NaN     NaN    NaN   2.0   2.0    NaN     NaN  NaN   NaN
#
# [5 rows x 158 columns]

# %%
#Setando o ano como Index
df_chart.set_index('ano', inplace=True)

#Trocando NaN por 0 
df_chart = df_chart.fillna(0)

# %%
#O cumsum faz o acumulado dos dados.
df_chart_acumulado = df_chart.cumsum()

# %%
#Instalamos o bar_chart_race

# !pip install bar_chart_race

# %%
import bar_chart_race as bcr

# %%
#Eu tive MUITA dificuldade com essa etapa pois é normal ocorrer vários erros, mas tem bastante tutorial na net que ajuda a sanar.
#Além disso o GPT foi crucial também haha
# !pip install ffmpeg-python

# %%
import matplotlib as mpl

# %%
#Essa foi uma etapa necessaria para forçar o matplot a localizar o arquivo ffmpeg, responsável por gerar o gráfico

mpl.rcParams['animation.ffmpeg_path'] = '/opt/homebrew/bin/ffmpeg'  # ajuste se for conda

# %%
#um checklist para avaliar se de fato deu certo
from matplotlib import animation
print(animation.writers.list())
# Out:
# ['pillow', 'ffmpeg', 'ffmpeg_file', 'html']

# %%
#código que de fato gera o arquivo responsável pelo chart race.
#documentação: https://www.dexplo.org/bar_chart_race/
import bar_chart_race as bcr

bcr.bar_chart_race(
    df=df_chart_acumulado,
    filename='saida__.mp4',  # ou None para exibir apenas no notebook
    orientation='h',
    sort='desc',
    n_bars=10,
    steps_per_period=80,
    period_length=2500,
    title='Campeões mais jogados por ano pelo MSI',
    interpolate_period=False
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# /opt/anaconda3/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# /opt/anaconda3/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# /opt/anaconda3/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(io.BytesIO())
# /opt/anaconda3/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
# ...
