# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/trv/Desktop/LoL/champions_stats.csv')

df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  \
# 0            18                          6.0   12     6  ...
# 1            13                          4.0    8     5  ...
# 2             2                          2.0    2     0  ...
# 3             8                          5.0    3     5  ...
# 4             4                          2.0    2     2  ...
#
#    kill_death_assist_ratio  creep_score  cs/min  gold  gold/min  damage  \
# ...

# %%
df['season'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 1340    12
# 1341    12
# 1342    12
# 1343    12
# 1344    12
# Name: season, Length: 1345, dtype: int64>

# %%
#df['ano'] = pd.to_datetime(2000 + 10 + df['season'], format='%Y') + pd.offsets.DateOffset(months=0, days=0)
#df['season'] = 'Season ' + df['season'].astype(str)
df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  \
# 0            18                          6.0   12     6  ...
# 1            13                          4.0    8     5  ...
# 2             2                          2.0    2     0  ...
# 3             8                          5.0    3     5  ...
# 4             4                          2.0    2     2  ...
#
#    kill_death_assist_ratio  creep_score  cs/min  gold  gold/min  damage  \
# ...

# %%
#df['ano'] = pd.to_datetime(df['ano'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#    season event      champion  games_contests  pick_ban_ratio  banned_games  \
# 0       1  Main          Nunu              27            96.4           9.0
# 1       1  Main       Alistar              25            89.3          12.0
# 2       1  Main        Rumble              23            82.1          21.0
# 3       1  Main      Vladimir              22            78.6          14.0
# 4       1  Main  Twisted Fate              22            78.6          18.0
#
#    played_games  played_by_number_of_players  win  lose  ...  \
# 0            18                          6.0   12     6  ...
# 1            13                          4.0    8     5  ...
# 2             2                          2.0    2     0  ...
# 3             8                          5.0    3     5  ...
# 4             4                          2.0    2     2  ...
#
#    kill_death_assist_ratio  creep_score  cs/min  gold  gold/min  damage  \
# ...

# %%
df_new = df[['champion', 'games_contests', 'season']]
df_new.head()
# Out:
#        champion  games_contests  season
# 0          Nunu              27       1
# 1       Alistar              25       1
# 2        Rumble              23       1
# 3      Vladimir              22       1
# 4  Twisted Fate              22       1

# %%
df_chart = df_new.pivot_table(
    index='season',
    columns='champion',
    values='games_contests',
    aggfunc='sum'  # ou 'mean', 'max', etc. conforme seu caso
)

df_chart = df_chart.rename_axis(None, axis=1).reset_index()

# %%
df_chart.head()
# Out:
#    season  Aatrox  Ahri  Akali  Alistar  Amumu  Anivia  Annie  Aphelios  Ashe  \
# 0       1     NaN   NaN    7.0     25.0   18.0    14.0   10.0       NaN  19.0
# 1       2     NaN   2.0    NaN     19.0    1.0    19.0    NaN       NaN   NaN
# 2       3    36.0  52.0    NaN      NaN    NaN     NaN   12.0       NaN   7.0
# 3       4     6.0  13.0    1.0     78.0    NaN     NaN    NaN       NaN   NaN
# 4       5     NaN   3.0    NaN     33.0    NaN     6.0   10.0       NaN  13.0
#
#    ...  Yasuo  Yone  Yorick  Yuumi   Zac   Zed  Ziggs  Zilean  Zoe  Zyra
# 0  ...    NaN   NaN     NaN    NaN   NaN   NaN    NaN     7.0  NaN   NaN
# 1  ...    NaN   NaN    11.0    NaN   NaN   NaN    NaN     2.0  NaN   4.0
# 2  ...    NaN   NaN     3.0    NaN  17.0  63.0    1.0     1.0  NaN  48.0
# 3  ...   30.0   NaN     NaN    NaN   NaN  38.0    2.0    75.0  NaN   NaN
# 4  ...   12.0   NaN     NaN    NaN   2.0   2.0    NaN     NaN  NaN   NaN
#
# [5 rows x 158 columns]

# %%
df_chart.set_index('season', inplace=True)

# Opcional: preencher NaNs com 0 (ou use outra lógica)
df_chart = df_chart.fillna(0)

# %%
df_chart_acumulado = df_chart.cumsum()

# %%
pip install bar_chart_race
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import bar_chart_race as bcr

# %%
pip install ffmpeg-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mpl

# %%
mpl.rcParams['animation.ffmpeg_path'] = '/opt/homebrew/bin/ffmpeg'  # ajuste se for conda

# %%
from matplotlib import animation
print(animation.writers.list())
# Out:
# ['pillow', 'ffmpeg', 'ffmpeg_file', 'html']

# %%
import matplotlib.animation as animation
print(animation.writers.list())
# Out:
# ['pillow', 'ffmpeg', 'ffmpeg_file', 'html']

# %%
print(bcr.__version__)
# Out:
# 0.1.0

# %%
import bar_chart_race as bcr

bcr.bar_chart_race(
    df=df_chart_acumulado,
    filename='saida__.mp4',  # ou None para exibir apenas no notebook
    orientation='h',
    sort='desc',
    n_bars=6,
    steps_per_period=60,
    period_length=2000,
    title='Campeões mais jogados por ano',
    interpolate_period=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       1 import bar_chart_race as bcr
#       3 bcr.bar_chart_race(
#       4     df=df_chart_acumulado,
#       5     filename='saida__.mp4',  # ou None para exibir apenas no notebook
#       6     orientation='h',
#       7     sort='desc',
#       8     n_bars=6,
#       9     steps_per_period=60,
#      10     period_length=2000,
#      11     title='Campeões mais jogados por ano',
# ---> 12     period_fmt=f'Season {season}',
#      13     interpolate_period=False
#      14 )
#
# NameError: name 'season' is not defined
